# %% [markdown]
# # Components in NLP
#
# ## 1 Common nlp libraries
# - Nltk library
# - Spacy library
# - TextBlob library
# - Gensim framework
# - Pattern framework
#
# ## 2 Components in NLP
# - There are mainly five components in NLP
#   - Lexical Anlysis
#   - Syntactic Analysis
#   - Semantic Anlysis
#   - Discouse Analysis
#   - Pragmatic Analysis
#
#
# ### 2.1 Lexical Anlysis
# - Lexical means relating to the words or vocabulary of a language
# - With lexical analysis we divide a whole chunk of text into
#   - Paragraphs
#   - Sentences
#   - Words
# - It involues identifying and analysing words 'struncture'
#
# ### 2.2 Syntactic Analysis
# - Syntactic means according to the syntax
# - In syntactic analysis it is the process of analysing the words in sentence
# - Analysing the grammar and arranging the words in a manner that shows the relationship among the words
# - Example
#   - The sentence "The shop goes to the house" does not pass means invaild
#
# ### 2.3 Semantic Analysis
# - Syntactic means relating to meaning in language
# - Semantic analysis draws the exact meaning for the words and it analyses the text to get meaningful
# - Example
#   - The sentences such as "hot ice-cream" do not pass or invalid
#
# ### 2.4 Discourse Analysis
# - Discourse means written or spoken communication
# - It considers the meaning of the sentance before it ends
# - Example
#   - The sentences such as "He works at Google" in this sentence "he" should be first word in sentence
#
# ### 2.5 Pragmatic Analysis
# - Pragmatic means practical, especially when making decisions
# - Pragmatic analysis deals with overall communication and interpretation of language
# - It deals with deriving meaning use of language in various situatuion
#
# ## 3. Use case
# - Process the below textual infomation
#
#
# # story_input.txt
#
# Once upon a time there was an old mother pig that had three little pigs and not enough food to feed them. So, when they were old enough, she sent them out into the world to seek their fortunes.
#
# The first little pig was very lazy. He didn't want to work at all and he built his house out of straw. The second little pig worked a little bit harder but he was somewhat lazy too and he builds his house out of sticks. Then, they sang and danced and played together and rest of the day.
#
# The third little pig worked hard all day and built his house with bricks. It was a sturdy house complete with a fine fireplace and chimney. It looked like it could withstand the strongest winds.

# %%
data=open("/Users/apple/Downloads/story_input.txt")
print(data)
# Out:
# <_io.TextIOWrapper name='/Users/apple/Downloads/story_input.txt' mode='r' encoding='UTF-8'>

# %%
data=open("/Users/apple/Downloads/story_input.txt")
print(data.read())
# Out:
# Once upon a time there was an old mother pig that had three little pigs and not enough food to feed them. So, when they were old enough, she sent them out into the world to seek their fortunes.
#
# The first little pig was very lazy. He didn't want to work at all and he built his house out of straw. The second little pig worked a little bit harder but he was somewhat lazy too and he builds his house out of sticks. Then, they sang and danced and played together and rest of the day.
#
# The third little pig worked hard all day and built his house with bricks. It was a sturdy house complete with a fine fireplace and chimney. It looked like it could withstand the strongest winds.

# %%
# Reading textual infomation from file 

data=open("/Users/apple/Downloads/story_input.txt")

text=data.read()
print(text)

print()
print(type(text))

print("Length of the text is :",len(text))
# Out:
# Once upon a time there was an old mother pig that had three little pigs and not enough food to feed them. So, when they were old enough, she sent them out into the world to seek their fortunes.
#
# The first little pig was very lazy. He didn't want to work at all and he built his house out of straw. The second little pig worked a little bit harder but he was somewhat lazy too and he builds his house out of sticks. Then, they sang and danced and played together and rest of the day.
#
# The third little pig worked hard all day and built his house with bricks. It was a sturdy house complete with a fine fireplace and chimney. It looked like it could withstand the strongest winds.
#
#
# <class 'str'>
# Length of the text is : 679

# %%
# Sentence tokenization

import nltk
from nltk import sent_tokenize

data=open("/Users/apple/Downloads/story_input.txt")
text=data.read()

sentences=sent_tokenize(text)

print("total sentences:",len(sentences))

for sent in sentences:
    print(sent)
# Out:
# total sentences: 9
# Once upon a time there was an old mother pig that had three little pigs and not enough food to feed them.
# So, when they were old enough, she sent them out into the world to seek their fortunes.
# The first little pig was very lazy.
# He didn't want to work at all and he built his house out of straw.
# The second little pig worked a little bit harder but he was somewhat lazy too and he builds his house out of sticks.
# Then, they sang and danced and played together and rest of the day.
# The third little pig worked hard all day and built his house with bricks.
# It was a sturdy house complete with a fine fireplace and chimney.
# It looked like it could withstand the strongest winds.

# %%
# Word tokenization

import nltk
from nltk import word_tokenize

data=open("/Users/apple/Downloads/story_input.txt")
text=data.read()

words=word_tokenize(text)

print(words)
# Out:
# ['Once', 'upon', 'a', 'time', 'there', 'was', 'an', 'old', 'mother', 'pig', 'that', 'had', 'three', 'little', 'pigs', 'and', 'not', 'enough', 'food', 'to', 'feed', 'them', '.', 'So', ',', 'when', 'they', 'were', 'old', 'enough', ',', 'she', 'sent', 'them', 'out', 'into', 'the', 'world', 'to', 'seek', 'their', 'fortunes', '.', 'The', 'first', 'little', 'pig', 'was', 'very', 'lazy', '.', 'He', 'did', "n't", 'want', 'to', 'work', 'at', 'all', 'and', 'he', 'built', 'his', 'house', 'out', 'of', 'straw', '.', 'The', 'second', 'little', 'pig', 'worked', 'a', 'little', 'bit', 'harder', 'but', 'he', 'was', 'somewhat', 'lazy', 'too', 'and', 'he', 'builds', 'his', 'house', 'out', 'of', 'sticks', '.', 'Then', ',', 'they', 'sang', 'and', 'danced', 'and', 'played', 'together', 'and', 'rest', 'of', 'the', 'day', '.', 'The', 'third', 'little', 'pig', 'worked', 'hard', 'all', 'day', 'and', 'built', 'his', 'house', 'with', 'bricks', '.', 'It', 'was', 'a', 'sturdy', 'house', 'complete', 'with', 'a', 'f
# ...

# %%
# Finding word frequency

import nltk
from nltk import word_tokenize
from nltk.probability import FreqDist

data=open("/Users/apple/Downloads/story_input.txt")
text=data.read()

words=word_tokenize(text)

fdist=FreqDist(words)
result=fdist.most_common(10)

for a in result:
    print(a)
# Out:
# ('.', 9)
# ('and', 8)
# ('little', 5)
# ('a', 4)
# ('was', 4)
# ('pig', 4)
# ('house', 4)
# ('to', 3)
# (',', 3)
# ('out', 3)

# %%
# Finding word frequency

import nltk
from nltk import word_tokenize
from nltk.probability import FreqDist

data=open("/Users/apple/Downloads/story_input.txt")
text=data.read()

words=word_tokenize(text)

fdist=FreqDist(words)
result=fdist.most_common(20)

for a in result:
    print(a)
# Out:
# ('.', 9)
# ('and', 8)
# ('little', 5)
# ('a', 4)
# ('was', 4)
# ('pig', 4)
# ('house', 4)
# ('to', 3)
# (',', 3)
# ('out', 3)
# ('the', 3)
# ('The', 3)
# ('he', 3)
# ('his', 3)
# ('of', 3)
# ('old', 2)
# ('enough', 2)
# ('them', 2)
# ('they', 2)
# ('lazy', 2)

# %% [markdown]
# # Note
# - Notice that the most used words are punctuation marks and stopwords
# - We will have to remove such words to analyse the actua text

# %%
# Plotting the frequency graph of words with punctuation 

import nltk
from nltk import word_tokenize
from nltk import FreqDist
import matplotlib.pyplot as plt

data=open("/Users/apple/Downloads/story_input.txt")
text=data.read()

words=word_tokenize(text)

fidist=FreqDist(words)
fidist.plot(10)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 6
#       4 from nltk import word_tokenize
#       5 from nltk import FreqDist
# ----> 6 import matplotlib.pyplot as plt
#       8 data=open("/Users/apple/Downloads/story_input.txt")
#       9 text=data.read()
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# !pip install matplotlib

# %%
# Plotting the frequency graph of words with punctuation 

import nltk
from nltk import word_tokenize
from nltk import FreqDist
import matplotlib.pyplot as plt

data=open("/Users/apple/Downloads/story_input.txt")
text=data.read()

words=word_tokenize(text)

fidist=FreqDist(words)
fidist.plot(10)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
import sys
# !{sys.executable} -m pip install matplotlib
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached pillow-12.1.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (8.8 kB)
# ...
#   Using cached pyparsing-3.3.1-py3-none-any.whl.metadata (5.6 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 3.9 MB/s  0:00:02 eta 0:00:01
# ...
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 3.7 MB/s  0:00:00 eta 0:00:01
# ...
# Using cached pillow-12.1.0-cp310-cp310-macosx_11_0_arm64.whl (4.7 MB)
# Using cached pyparsing-3.3.1-py3-none-any.whl (121 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib]7 [matplotlib]
# ...

# %%
import sys
print(sys.executable)
# Out:
# /opt/miniconda3/envs/tf_m1/bin/python

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/apple/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Plotting the frequency graph of words with punctuation 


import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
import matplotlib.pyplot as plt

# download tokenizer (run once)
nltk.download('punkt')

# read file
with open("/Users/apple/Downloads/story_input.txt", "r") as data:
    text = data.read()

# tokenize words (includes punctuation)
words = word_tokenize(text)

# frequency distribution
fdist = FreqDist(words)

# plot top 10 words
fdist.plot(10)
plt.show()
# Out:
# [nltk_data] Downloading package punkt to /Users/apple/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# - In the graph above notice that a period "." is used nine times in our text
# - Analytically speaking punctuation marks are not that important for natural language processing
# - Therefore, in the next step , we will br removing such punctuation marks

# %%
# Removing the punctuation marks 

import nltk
from nltk import word_tokenize

data=open("/Users/apple/Downloads/story_input.txt")
text=data.read()

word=word_tokenize(text)

words_no_punc=[]

for w in word:
    if w.isalpha():
        words_no_punc.append(w.lower())

print(words_no_punc)

print()
print("length of words : ",len(words_no_punc))
# Out:
# ['once', 'upon', 'a', 'time', 'there', 'was', 'an', 'old', 'mother', 'pig', 'that', 'had', 'three', 'little', 'pigs', 'and', 'not', 'enough', 'food', 'to', 'feed', 'them', 'so', 'when', 'they', 'were', 'old', 'enough', 'she', 'sent', 'them', 'out', 'into', 'the', 'world', 'to', 'seek', 'their', 'fortunes', 'the', 'first', 'little', 'pig', 'was', 'very', 'lazy', 'he', 'did', 'want', 'to', 'work', 'at', 'all', 'and', 'he', 'built', 'his', 'house', 'out', 'of', 'straw', 'the', 'second', 'little', 'pig', 'worked', 'a', 'little', 'bit', 'harder', 'but', 'he', 'was', 'somewhat', 'lazy', 'too', 'and', 'he', 'builds', 'his', 'house', 'out', 'of', 'sticks', 'then', 'they', 'sang', 'and', 'danced', 'and', 'played', 'together', 'and', 'rest', 'of', 'the', 'day', 'the', 'third', 'little', 'pig', 'worked', 'hard', 'all', 'day', 'and', 'built', 'his', 'house', 'with', 'bricks', 'it', 'was', 'a', 'sturdy', 'house', 'complete', 'with', 'a', 'fine', 'fireplace', 'and', 'chimney', 'it', 'looked', 'lik
# ...

# %%
# Plotting the frequency graph of words with punctuation 

import nltk
from nltk import word_tokenize

data=open("/Users/apple/Downloads/story_input.txt")
text=data.read()

word=word_tokenize(text)

words_no_punc=[]

for w in word:
    if w.isalpha():
        words_no_punc.append(w.lower())


fidist=FreqDist(words_no_punc)
fidist.plot(10)
# Out:
# <Axes: xlabel='Samples', ylabel='Counts'>

# %%
import nltk
from nltk import word_tokenize

data=open("/Users/apple/Downloads/story_input.txt")
text=data.read()

word=word_tokenize(text)

words_no_punc=[]

for w in word:
    if w.isalpha():
        words_no_punc.append(w.lower())

fdist=FreqDist(words)
result=fdist.most_common(20)

for a in result:
    print(a)
# Out:
# ('.', 9)
# ('and', 8)
# ('little', 5)
# ('a', 4)
# ('was', 4)
# ('pig', 4)
# ('house', 4)
# ('to', 3)
# (',', 3)
# ('out', 3)
# ('the', 3)
# ('The', 3)
# ('he', 3)
# ('his', 3)
# ('of', 3)
# ('old', 2)
# ('enough', 2)
# ('them', 2)
# ('they', 2)
# ('lazy', 2)

# %%
# list of the stop words

from nltk.corpus import stopwords

stopword=stopwords.words('english')

print(stopword)
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 's
# ...

# %% [markdown]
# # 1. Loading the text data
# # 2. Displaying text data
# # 3. work tokenization
# # 4. plotting the frequence of words
# # 5. removing special symbols
# # 6. plotting the frequence of words
# # 7. Lets remove stop words:)

# %%
# Removing the stop words

import nltk
from nltk import word_tokenize
from nltk.probability import FreqDist
import matplotlib.pyplot  as plt
from nltk.corpus import stopwords


data=open("/Users/apple/Downloads/story_input.txt")
text=data.read()

stopword=stopwords.words('english')
words=word_tokenize(text)

words_no_punc=[]

for w in words:
    if w.isalpha():
        words_no_punc.append(w.lower())

clean_words=[]

for w in words_no_punc:
    if w not in stopwords:
        clean_words.append(w)


print(clean_words)
print("length of clean words,",len(clean_words))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 25
#      22 clean_words=[]
#      24 for w in words_no_punc:
# ---> 25     if w not in stopwords:
#      26         clean_words.append(w)
#      29 print(clean_words)
#
# TypeError: argument of type 'WordListCorpusReader' is not iterable

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /Users/apple/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/apple/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Removing the stop words

import nltk
from nltk import word_tokenize
from nltk.corpus import stopwords

# download required resources (run once)
nltk.download('punkt')
nltk.download('stopwords')

# read text file
with open("/Users/apple/Downloads/story_input.txt", "r") as data:
    text = data.read()

# tokenize
words = word_tokenize(text)

# load stopwords
stopword = stopwords.words('english')

# remove punctuation and lowercase
words_no_punc = []
for w in words:
    if w.isalpha():
        words_no_punc.append(w.lower())

# remove stopwords
clean_words = []
for w in words_no_punc:
    if w not in stopword:
        clean_words.append(w)

print(clean_words)
print("Length of clean words:", len(clean_words))
# Out:
# ['upon', 'time', 'old', 'mother', 'pig', 'three', 'little', 'pigs', 'enough', 'food', 'feed', 'old', 'enough', 'sent', 'world', 'seek', 'fortunes', 'first', 'little', 'pig', 'lazy', 'want', 'work', 'built', 'house', 'straw', 'second', 'little', 'pig', 'worked', 'little', 'bit', 'harder', 'somewhat', 'lazy', 'builds', 'house', 'sticks', 'sang', 'danced', 'played', 'together', 'rest', 'day', 'third', 'little', 'pig', 'worked', 'hard', 'day', 'built', 'house', 'bricks', 'sturdy', 'house', 'complete', 'fine', 'fireplace', 'chimney', 'looked', 'like', 'could', 'withstand', 'strongest', 'winds']
# Length of clean words: 65
# [nltk_data] Downloading package punkt to /Users/apple/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/apple/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import nltk
from nltk import word_tokenize
from nltk.corpus import stopwords

# download required resources (run once)
nltk.download('punkt')
nltk.download('stopwords')

# read text file
with open("/Users/apple/Downloads/story_input.txt", "r") as data:
    text = data.read()

# tokenize
words = word_tokenize(text)

# load stopwords
stopword = stopwords.words('english')

# remove punctuation and lowercase
words_no_punc = []
for w in words:
    if w.isalpha():
        words_no_punc.append(w.lower())

# remove stopwords
clean_words = []
for w in words_no_punc:
    if w not in stopword:
        clean_words.append(w)

fidist=FreqDist(clean_words)
result=fidist.most_common(10)
for a in result:
    print(a)

fidist.plot(10)
# Out:
# ('little', 5)
# ('pig', 4)
# ('house', 4)
# ('old', 2)
# ('enough', 2)
# ('lazy', 2)
# ('built', 2)
# ('worked', 2)
# ('day', 2)
# ('upon', 1)
# [nltk_data] Downloading package punkt to /Users/apple/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/apple/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# <Axes: xlabel='Samples', ylabel='Counts'>

# %% [markdown]
# ## 4. Word Cloud
# * Word Cloud is a data visualization technique.
# *  In which words from a given text display on the main chart.
# * In this technique, more frequent or essential words display in a larger and bolder font.
# * Less frequent or essential words display in smaller or thinner fonts.
# * It is a beneficial technique in NLP that gives us a glance at what text should be analysed.

# %%
import matplotlib.pyplot as plt 
from wordcloud import WordCloud

text="Datascience having good carrer path , Datascience is cutting edge technology Datascience course is existing in nit, Daniel used to tech Datascience, if we learn Datascience then we will get package "

wc=WordCloud()
wc.generate(text)

plt.figure(figsize=(12,12))
plt.imshow(wc)
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 from wordcloud import WordCloud
#       4 text="Datascience having good carrer path , Datascience is cutting edge technology Datascience course is existing in nit, Daniel used to tech Datascience, if we learn Datascience then we will get package "
#       6 wc=WordCloud()
#
# ModuleNotFoundError: No module named 'wordcloud'

# %%
# !pip install wordclound
# Out:
# ERROR: Could not find a version that satisfies the requirement wordclound (from versions: none)
# ERROR: No matching distribution found for wordclound

# %%
conda install -c conda-forge wordcloud
# Out:
# Jupyter detected...
# 2 channel Terms of Service accepted
# doneieving notices: -
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# doneecting package metadata (repodata.json): |
# doneing environment: |
#
# ## Package Plan ##
#
#   environment location: /opt/miniconda3/envs/tf_m1
#
#   added / updated specs:
#     - wordcloud
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotli-1.2.0               |       h7d5ae5b_1          20 KB  conda-forge
#     brotli-bin-1.2.0           |       hc919400_1          18 KB  conda-forge
#     ca-certificates-2026.1.4   |       hbd8a1cb_0         143 KB  conda-forge
#     certifi-2026.1.4           |     pyhd8ed1ab_0         147 KB  conda-forge
#     contourpy-1.2.1            |  py310h21239e6_0         221 KB  conda-forge
#     cycler-0.12.1              |     pyhcf101f3_2          14 KB  conda-forge
# ...

# %%
pip install wordcloud
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

text = """
Datascience having good career path,
Datascience is cutting edge technology.
Datascience course is existing in NIT.
Daniel used to teach Datascience.
If we learn Datascience then we will get package.
"""

wc = WordCloud(
    width=800,
    height=400,
    background_color='white'
)

wc.generate(text)

plt.figure(figsize=(12, 6))
plt.imshow(wc)
plt.axis('off')
plt.show()

# %% [markdown]
# 1. Text file
# 2. Loading file using open) function
# 3. Calling read) method to get text data
# 4. word tokenization
# 5. word frequency
# 6. plotting the count of words
# 7. remove special symbols
# 8. word frequency
# 9. plotting the count of words
# 10. remove stop words
# 11. word frequency
# 12. plotting the count of words
